# %%
import pandas as pd
df = pd.read_excel(r"C:\Users\Yamin Hossain\Downloads\crop yeild data sheet - Copy.xlsx")
print(df)
# Out:
#     Rain Fall (mm)  Fertilizer  Temperatue  Nitrogen (N)  Phosphorus (P)  \
# 0             1230          80          28            80              24
# 1              480          60          36            70              20
# 2             1250          75          29            78              22
# 3              450          65          35            70              19
# 4             1200          80          27            79              22
# ..             ...         ...         ...           ...             ...
# 94            1250          77          28            78              23
# 95             425          60          39            65              19
# 96            1220          79          28            77              23
# 97             480          65          36            68              21
# 98            1230          80          28            80              24
#
#     Potassium (K)  Yeild (Q/acre)
# 0              20            12.0
# 1              18             8.0
# 2              19            11.0
# 3              18             9.0
# 4              19            11.0
# ..            ...             ...
# 94             20             9.0
# 95             17             6.5
# 96             21            10.5
# 97             16             7.0
# 98             20            12.0
#
# [99 rows x 7 columns]

# %%
df_max_scaled = df.copy()
for column in df_max_scaled.columns:
    df_max_scaled[column] = df_max_scaled[column] / df_max_scaled[column].abs().max()
display(df_max_scaled)
# Out:
#     Rain Fall (mm)  Fertilizer  Temperatue  Nitrogen (N)  Phosphorus (P)  \
# 0         0.946154      1.0000       0.700        1.0000            0.96
# 1         0.369231      0.7500       0.900        0.8750            0.80
# 2         0.961538      0.9375       0.725        0.9750            0.88
# 3         0.346154      0.8125       0.875        0.8750            0.76
# 4         0.923077      1.0000       0.675        0.9875            0.88
# ..             ...         ...         ...           ...             ...
# 94        0.961538      0.9625       0.700        0.9750            0.92
# 95        0.326923      0.7500       0.975        0.8125            0.76
# 96        0.938462      0.9875       0.700        0.9625            0.92
# 97        0.369231      0.8125       0.900        0.8500            0.84
# 98        0.946154      1.0000       0.700        1.0000            0.96
#
#     Potassium (K)  Yeild (Q/acre)
# 0        0.909091        1.000000
# 1        0.818182        0.666667
# 2        0.863636        0.916667
# 3        0.818182        0.750000
# 4        0.863636        0.916667
# ..            ...             ...
# 94       0.909091        0.750000
# 95       0.772727        0.541667
# 96       0.954545        0.875000
# 97       0.727273        0.583333
# 98       0.909091        1.000000
#
# [99 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
df_max_scaled.plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
df_min_max_scaled = df.copy()
for column in df_min_max_scaled.columns:
    df_min_max_scaled[column] = (df_min_max_scaled[column] - (df_min_max_scaled[column].min()) / df_min_max_scaled[column].min())
print(df_min_max_scaled)
# Out:
#     Rain Fall (mm)  Fertilizer  Temperatue  Nitrogen (N)  Phosphorus (P)  \
# 0           1229.0        79.0        27.0          79.0            23.0
# 1            479.0        59.0        35.0          69.0            19.0
# 2           1249.0        74.0        28.0          77.0            21.0
# 3            449.0        64.0        34.0          69.0            18.0
# 4           1199.0        79.0        26.0          78.0            21.0
# ..             ...         ...         ...           ...             ...
# 94          1249.0        76.0        27.0          77.0            22.0
# 95           424.0        59.0        38.0          64.0            18.0
# 96          1219.0        78.0        27.0          76.0            22.0
# 97           479.0        64.0        35.0          67.0            20.0
# 98          1229.0        79.0        27.0          79.0            23.0
#
#     Potassium (K)  Yeild (Q/acre)
# 0            19.0            11.0
# 1            17.0             7.0
# 2            18.0            10.0
# 3            17.0             8.0
# 4            18.0            10.0
# ..            ...             ...
# 94           19.0             8.0
# 95           16.0             5.5
# 96           20.0             9.5
# 97           15.0             6.0
# 98           19.0            11.0
#
# [99 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
df_min_max_scaled.plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
df_z_scaled = df.copy()

for column in df_z_scaled.columns:
    df_z_scaled[column] = (df_z_scaled[column] - df_z_scaled[column].mean())/df_z_scaled[column].std()
display(df_z_scaled)
# Out:
#     Rain Fall (mm)  Fertilizer  Temperatue  Nitrogen (N)  Phosphorus (P)  \
# 0         0.950404    1.215763   -0.809741      1.387227        1.469844
# 1        -0.924396   -0.778612    0.664546     -0.110434       -0.579657
# 2         1.000398    0.717169   -0.625455      1.087695        0.445094
# 3        -0.999388   -0.280018    0.480260     -0.110434       -1.092032
# 4         0.875412    1.215763   -0.994027      1.237461        0.445094
# ..             ...         ...         ...           ...             ...
# 94        1.000398    0.916607   -0.809741      1.087695        0.957469
# 95       -1.061882   -0.778612    1.217404     -0.859264       -1.092032
# 96        0.925406    1.116044   -0.809741      0.937929        0.957469
# 97       -0.924396   -0.280018    0.664546     -0.409966       -0.067282
# 98        0.950404    1.215763   -0.809741      1.387227        1.469844
#
#     Potassium (K)  Yeild (Q/acre)
# 0        1.067211        1.500327
# 1       -0.033350       -0.534363
# 2        0.516930        0.991654
# 3       -0.033350       -0.025691
# 4        0.516930        0.991654
# ..            ...             ...
# 94       1.067211       -0.025691
# 95      -0.583631       -1.297371
# 96       1.617492        0.737318
# 97      -1.133912       -1.043035
# 98       1.067211        1.500327
#
# [99 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
df_z_scaled.plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
import numpy as np
from sklearn.preprocessing import FunctionTransformer
df_log_scaled = df.copy()
transformer = FunctionTransformer(np.log1p)
t1 = transformer.transform(df_log_scaled)
print(t1)
# Out:
#     Rain Fall (mm)  Fertilizer  Temperatue  Nitrogen (N)  Phosphorus (P)  \
# 0         7.115582    4.394449    3.367296      4.394449        3.218876
# 1         6.175867    4.110874    3.610918      4.262680        3.044522
# 2         7.131699    4.330733    3.401197      4.369448        3.135494
# 3         6.111467    4.189655    3.583519      4.262680        2.995732
# 4         7.090910    4.394449    3.332205      4.382027        3.135494
# ..             ...         ...         ...           ...             ...
# 94        7.131699    4.356709    3.367296      4.369448        3.178054
# 95        6.054439    4.110874    3.688879      4.189655        2.995732
# 96        7.107425    4.382027    3.367296      4.356709        3.178054
# 97        6.175867    4.189655    3.610918      4.234107        3.091042
# 98        7.115582    4.394449    3.367296      4.394449        3.218876
#
#     Potassium (K)  Yeild (Q/acre)
# 0        3.044522        2.564949
# 1        2.944439        2.197225
# 2        2.995732        2.484907
# 3        2.944439        2.302585
# 4        2.995732        2.484907
# ..            ...             ...
# 94       3.044522        2.302585
# 95       2.890372        2.014903
# 96       3.091042        2.442347
# 97       2.833213        2.079442
# 98       3.044522        2.564949
#
# [99 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
df_log_scaled.plot(kind = 'bar')
# Out:
# <AxesSubplot:>
